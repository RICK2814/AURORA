# %% [markdown]
# # Data Exploration - Sentinel-2 Imagery
#
# This notebook explores Sentinel-2 data for mining activity monitoring.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path().parent.parent))

import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import rasterio
from rasterio.plot import show

from src.utils import load_boundary
from src.data_acquisition import download_sentinel2_data

# %% [markdown]
# ## Load Boundaries

# %%
# Load mine boundary
mine_boundary = load_boundary("data/boundaries/mine_boundary.shp")
print(f"Mine boundary CRS: {mine_boundary.crs}")
print(f"Mine boundary bounds: {mine_boundary.total_bounds}")

# Visualize
mine_boundary.plot(figsize=(10, 10))
plt.title("Mine Boundary")
plt.show()
